# %%
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.8.4
# Location         C:\Users\abhis\anaconda3\Lib\site-packages\spacy
# Platform         Windows-11-10.0.26100-SP0
# Python version   3.12.7
# Pipelines        en_core_web_sm (3.8.0)

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('tweets.csv', encoding = 'ISO-8859-1')

# %%
df
# Out:
#                                                    text favorited  \
# 0     RT @rssurjewala: Critical question: Was PayTM ...     False
# 1     RT @Hemant_80: Did you vote on #Demonetization...     False
# 2     RT @roshankar: Former FinSec, RBI Dy Governor,...     False
# 3     RT @ANI_news: Gurugram (Haryana): Post office ...     False
# 4     RT @satishacharya: Reddy Wedding! @mail_today ...     False
# ...                                                 ...       ...
# 5152  @thehill To The Hill. Shame on you for your an...     False
# 5153  RT @saxenavishakha: Ghost of demonetization re...     False
# 5154  N d modi fans-d true nationalists of the count...     False
# 5155  RT @Stupidosaur: @Vidyut B team of BJP. CIA ba...     False
# 5156  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...     False
#
#       favoriteCount replyToSN              created truncated    replyToSID  \
# 0               0.0       NaN  2016-11-23 18:40:30     False           NaN
# 1               0.0       NaN  2016-11-23 18:40:29     False           NaN
# 2               0.0       NaN  2016-11-23 18:40:03     False           NaN
# 3               0.0       NaN  2016-11-23 18:39:59     False           NaN
# 4               0.0       NaN  2016-11-23 18:39:39     False           NaN
# ...             ...       ...                  ...       ...           ...
# 5152            0.0   thehill  2017-04-11 14:40:57     False  8.518033e+17
# 5153            0.0       NaN  2017-04-11 14:26:38     False           NaN
# 5154            0.0       NaN  2017-04-11 14:19:51      True           NaN
# 5155            0.0       NaN  2017-04-11 14:13:14     False           NaN
# 5156            1.0    Vidyut  2017-04-11 14:13:06      True  8.516909e+17
#
#                 id  replyToUID  \
# 0     8.014957e+17         NaN
# 1     8.014957e+17         NaN
# 2     8.014955e+17         NaN
# 3     8.014955e+17         NaN
# 4     8.014954e+17         NaN
# ...            ...         ...
# 5152  8.518073e+17   1917731.0
# 5153  8.518037e+17         NaN
# 5154  8.518020e+17         NaN
# 5155  8.518003e+17         NaN
# 5156  8.518003e+17  15199808.0
#
#                                            statusSource       screenName  \
# 0     <a href="http://twitter.com/download/android" ...  HASHTAGFARZIWAL
# 1     <a href="http://twitter.com/download/android" ...   PRAMODKAUSHIK9
# 2     <a href="http://twitter.com/download/android" ...  rahulja13034944
# 3     <a href="http://twitter.com/download/android" ...        deeptiyvd
# 4     <a href="http://cpimharyana.com" rel="nofollow...        CPIMBadli
# ...                                                 ...              ...
# 5152  <a href="http://twitter.com" rel="nofollow">Tw...       Reaganite8
# 5153  <a href="http://twitter.com/download/android" ...     MuzzammilAap
# 5154  <a href="http://twitter.com/download/android" ...       JusteyAlex
# 5155  <a href="http://twitter.com" rel="nofollow">Tw...      Stupidosaur
# 5156  <a href="http://twitter.com" rel="nofollow">Tw...      Stupidosaur
#
#       retweetCount isRetweet retweeted
# 0            331.0      True     False
# 1             66.0      True     False
# 2             12.0      True     False
# 3            338.0      True     False
# 4            120.0      True     False
# ...            ...       ...       ...
# 5152           0.0     False     False
# 5153           4.0      True     False
# 5154           0.0     False     False
# 5155           2.0      True     False
# 5156           2.0     False     False
#
# [5157 rows x 14 columns]

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
combined_tweets = ''.join(df.text.values)

# %%
doc= nlp(combined_tweets)

# %%
# Function for generating word frequency
def gen_freq(tokens):
    
    # Creating a pandas series with word frequencies
    word_freq = pd.Series([token.text for token in tokens]).value_counts()
    
    # Printing frequencies
    print(word_freq[:20])
    
    return word_freq

# %%
word_freq = gen_freq(doc)
# Out:
# #                 5360
# demonetization    2236
# .                 2158
# :                 2030
# ,                 1731
# Demonetization    1664
# to                1659
# the               1591
# of                1588
# in                1343
# \r\n              1288
# is                1087
# on                 946
#                   895
# a                  816
#                   756
# and                709
# 's                 663
# -                  650
# for                619
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Function for generating wordcloud
def generate_wordcloud(data):
    # Creating a wordcloud
    wc = WordCloud(width=400, height=330, max_words=200,background_color='white').generate_from_frequencies(data)
    
    # Setting Figure Size
    plt.figure(figsize=(14,12))
    
    # Display wordcloud as image
    plt.imshow(wc, interpolation='bilinear')
    
    # Removing all the axes
    plt.axis("off")
    
    plt.show()

# %%
print('No. of unique words =>', len(word_freq))
# Out:
# No. of unique words => 17361

# %%
generate_wordcloud(word_freq)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 generate_wordcloud(word_freq)
#
# Cell In[70], line 4, in generate_wordcloud(data)
#       2 def generate_wordcloud(data):
#       3     # Creating a wordcloud
# ----> 4     wc = WordCloud(width=400, height=330, max_words=200,background_color='white').generate_from_frequencies(data)
#       6     # Setting Figure Size
#       7     plt.figure(figsize=(14,12))
#
# File ~\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:511, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     508 transposed_font = ImageFont.TransposedFont(
#     509     font, orientation=orientation)
#     510 # get size of resulting text
# --> 511 box_size = draw.textbbox((0, 0), word, font=transposed_font, anchor="lt")
#     512 # find possible places using integral image:
#     513 result = occupancy.sample_position(box_size[3] + self.margin,
#     514                                    box_size[2] + self.margin,
#     515                                    random_state)
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageDraw.py:844, in ImageDraw.textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color, font_size)
#     841     font = self._getfont(font_size)
#     843 if self._multiline_check(text):
# --> 844     return self.multiline_textbbox(
#     845         xy,
#     846         text,
#     847         font,
#     848         anchor,
#     849         spacing,
#     850         align,
#     851         direction,
#     852         features,
#     853         language,
#     854         stroke_width,
#     855         embedded_color,
#     856     )
#     858 mode = "RGBA" if embedded_color else self.fontmode
#     859 bbox = font.getbbox(
#     860     text, mode, direction, features, language, stroke_width, anchor
#     861 )
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageDraw.py:891, in ImageDraw.multiline_textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color, font_size)
#     889 elif anchor[1] in "tb":
#     890     msg = "anchor not supported for multiline text"
# --> 891     raise ValueError(msg)
#     893 if font is None:
#     894     font = self._getfont(font_size)
#
# ValueError: anchor not supported for multiline text
